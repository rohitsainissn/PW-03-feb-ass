# %% [markdown]
# Q- 1 Who developed Python?
#
# Ans :- Guido van Rossum
#
#
# Q-2 Which type of programming does python support
#
# Ans:- Python support multi paradigm language, it support object oriented programming and structured programming language. also support functional programming and aspect-oriented programming.
#
#
# Q-3 Is python case sensitive when dealing with identifiers?
#
# Ans:-Yes
#
#
# Q-4 What is the corret extension of the python file?
# Ans:- .py
#
#
# Q-5 Is Python code compiled or interpreted?
#
# Ans:- Interpreted
#
#
# Q-6 Name a few blocks of code used to define in Python language?
#
# Ans:- Module, function and class are few blocks of code used to define in Python.
#
#
# Q-7 State a character used to give single-line comments in Python?
#
# Ans:- # is used to give single-line comments.
#
#
# Q-8 Mention functions which can help us to find the version of python that we are currntly working.
#
# Ans:- sys.version
#
#
# Q-9 Python supports the creation of anonymous functions at runtime, using a construct called _____?
# Ans:- lambda
#
#
# Q-10 What does pip stand for python?
#
# Ans:- pip (pip install packages) is used to install python packages and their dependencies.
#
# Q-11 Mention a few built-in functions in python?
#
# Ans:- print(), type(), input(), max(), round() dir(), pow()
#
#
# Q-12 Max length of identifier?
#
# Ans:- 79 characters
#
#
# Q-13 Benefits of Python?
#
# Ans:-
#
# easy to learn
#
# easy to understand written code
#
# large supporting community
#
# videly available liberaries
#
# High level language
#
# supports oops
#
# portable across operating systems
#
#
# Q-14 How is memory manage in Python?
#
# Ans:- Memory is managed by creating a private heap containing all Python objects and data structures.
#
# Q-15 How to install python on Windows and set path variables
#
# Ans:- Install python from this link https://www.python.org/downloads/
#
# Then go to advanced system settings and add new variable and name it as PYTHON_NAME and paste the copied path.
# Then look for the path variable, select it's value and select edit
# Add a semicolon towards the end of the value if it's not present and then type %PYTHON_HOME%
#
# Q-16 Is indentation required in python?
#
# Ans:- Yes Python use indentation, python does not use {} to define a block of code like in C, C++.
