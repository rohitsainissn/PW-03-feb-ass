# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?
#
# Ans 10683 rows × 11 columns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_excel('flight_price.xlsx')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
df.hist('Price',bins=20)
# Out:
# array([[<AxesSubplot: title={'center': 'Price'}>]], dtype=object)

# %% [markdown]
# Prices are right skewed distribution

# %%
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
mx = df.Price.max()
mn = df.Price.min()
print(f'max price is {mx}, min price is {mn}, and the range is {mx-mn}')
# Out:
# max price is 79512, min price is 1759, and the range is 77753

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(x='Airline', y='Price', data=df, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
fig.show()

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.
#
# Ans:- Yes there are outliers in the dataset, potential outliers are shown above, they will impact our analysis, as they are not in the overall range of data, hence it will be hard for the model where gradient descent or l2 cost function is used because it will impact our model to form a generalize model.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?
#
# Ans:- i will use date column to make new month column, then plot the month vs price histogram, this histogram will give me the idea in which season our sales are increasing.

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?
#
# Ans:- i will use date of month vs price histogram, month vs price histogram, boxplot of weekday and weekends, histogram of days vs price, airline vs price boxplot.
#
# These visualisation will give the desire result

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?
#
# Ans:- Ans:- i will use date of month vs price histogram, month vs price histogram, boxplot of weekday and weekends, histogram of days vs price, airline vs price boxplot.
#
# These visualisation will give the desire result
# After observing various factors I will compose the desire report to the management team based on the observations

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?
#
# Ans :- dimension is (10841, 13) and 10841 rows × 13 columns

# %%
df=pd.read_csv('google.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (10358, 13)

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(data = df, x='Category',y='Rating', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
fig.show()

# %%
df.Category.value_counts()
# Out:
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %% [markdown]
# as we can see that there is a wrong value of 1.9 in category column, hence we delete this value and replot boxplot

# %%
index_names = df[df['Category'] == '1.9'].index
df.drop(index_names, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(data = df, x='Category',y='Rating', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
fig.show()

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Ans:- Yes, there are missing values, and missing values will impact our analysis as 1474 rating are missing hence 15.5% data we might loss if we remove this missing value hence cause a lose of information.

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
df['Size']=  df['Size'].str.replace('M','000')
df['Size']=  df['Size'].str.replace('k','')

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data = df, x='Size', y ='Rating', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
fig.show()

# %% [markdown]
# As size increase the no of apps decreases, but the Rating will remain nearly constant.

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df['Price']=  df['Price'].str.replace('$','')
df['Price']= df.Price.astype(float)

# %%
df.Type.value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
sns.barplot(data=df, x='Type', y='Price')
# Out:
# <AxesSubplot: xlabel='Type', ylabel='Price'>

# %% [markdown]
# Ans:- as the app type is paid, it have a price, otherwise if type is free its price is zero.

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
df.Installs=  df['Installs'].str.replace('+','')
df.Installs=  df['Installs'].str.replace(',','')
df.Installs= df.Installs.astype(float)

# %%
df_freq = df[['App','Installs']]

# %%
df_freq.sort_values(by='Installs', ascending=False, inplace=True)

# %%
df_freq.head(10)
# Out:
#                                App      Installs
# 341                       Hangouts  1.000000e+09
# 3928                       YouTube  1.000000e+09
# 451                          Gmail  1.000000e+09
# 3996  Google Chrome: Fast & Secure  1.000000e+09
# 1700                Subway Surfers  1.000000e+09
# 3454                  Google Drive  1.000000e+09
# 2808                 Google Photos  1.000000e+09
# 865              Google Play Games  1.000000e+09
# 2853                 Google Photos  1.000000e+09
# 411   Google Chrome: Fast & Secure  1.000000e+09

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %% [markdown]
# Ans:- we will recommend the app category with high rating, high number of installs and more reviews with genres of high rating, high number of installs, hence best features must be recommended are category, rating, reviews, installs, genres.

# %%
df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#   Reviews   Size  Installs  Type  Price Content Rating        Genres  \
# 0     159  19000   10000.0  Free    0.0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %% [markdown]
# Ans:- We have to first take out the list of best 100 apps, for that we will use category to know which category is best for creating app by knowing its rating, reviews and instlls,we have to choose only app who used to update and suitable to vast android ver, we have to get best genres where chances are high for an app to get successed, then we will collect the list of best apps and search the developer who have designed most of the apps.
#
# best features are :- category, rating, reviews, installs, genres, last update, current ver, android ver
#
# Data visualizations:- hist of category with installs:- to know best categories
#
# hist of genres with installs to know best genres
#
# hist of app with install to know best apps.
#
# list of apps with best genres and category.
# groupby these best apps with developer name.

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?

# %% [markdown]
# To identify the best time to launch a new app on the Google Playstore dataset, the following features can be analyzed:
#
# App ratings and reviews: Analyzing the ratings and reviews of the existing apps in the Playstore can provide insights into user behavior and preferences.
#
# App downloads and usage: Analyzing the number of downloads and usage of the existing apps can provide insights into the popularity of certain categories of apps and user engagement.
#
# User demographics: Analyzing the demographics of the users who have downloaded and used the existing apps can provide insights into the target audience for the new app.
#
# Seasonal trends: Analyzing the seasonal trends in app downloads and usage can provide insights into the best time to launch the new app.
#
# Competitor analysis: Analyzing the performance of the existing apps in the same category as the new app can provide insights into the competition and the potential demand for the new app.
#
# To present these findings, the following data visualizations can be used:
#
# Line charts and bar graphs to represent the trends in app downloads and usage over time.
#
# Pie charts and histograms to represent the user demographics and preferences.
#
# Heat maps and scatter plots to represent the correlations between different variables, such as the ratings and reviews of the apps.
#
# Bubble charts and radar charts to represent the performance of the existing apps in the same category as the new app.
